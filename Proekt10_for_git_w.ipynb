# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Изменение-типа-данных" data-toc-modified-id="Изменение-типа-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Изменение типа данных</a></span></li><li><span><a href="#Поиск-дубликатов" data-toc-modified-id="Поиск-дубликатов-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Поиск дубликатов</a></span></li></ul></li><li><span><a href="#Приоритизация-гипотез." data-toc-modified-id="Приоритизация-гипотез.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Приоритизация гипотез.</a></span><ul class="toc-item"><li><span><a href="#Применение-фреймворка-ICE-для-приоритизации-гипотез.-Сортировка-их-по-убыванию-приоритета." data-toc-modified-id="Применение-фреймворка-ICE-для-приоритизации-гипотез.-Сортировка-их-по-убыванию-приоритета.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Применение фреймворка ICE для приоритизации гипотез. Сортировка их по убыванию приоритета.</a></span></li><li><span><a href="#Применение-фреймворка-RICE-для-приоритизации-гипотез.-Сортировка-их-по-убыванию-приоритета." data-toc-modified-id="Применение-фреймворка-RICE-для-приоритизации-гипотез.-Сортировка-их-по-убыванию-приоритета.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Применение фреймворка RICE для приоритизации гипотез. Сортировка их по убыванию приоритета.</a></span></li><li><span><a href="#Разница-в-приоритизации-гипотез-при-применении-RICE-вместо-ICE.-Причины-различия-результатов." data-toc-modified-id="Разница-в-приоритизации-гипотез-при-применении-RICE-вместо-ICE.-Причины-различия-результатов.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Разница в приоритизации гипотез при применении RICE вместо ICE. Причины различия результатов.</a></span></li></ul></li><li><span><a href="#Анализ-A/B-теста" data-toc-modified-id="Анализ-A/B-теста-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Анализ A/B-теста</a></span><ul class="toc-item"><li><span><a href="#Построим-график-кумулятивной-выручки-по-группам.-Сделаем-выводы-и-предположения." data-toc-modified-id="Построим-график-кумулятивной-выручки-по-группам.-Сделаем-выводы-и-предположения.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Построим график кумулятивной выручки по группам. Сделаем выводы и предположения.</a></span></li><li><span><a href="#Построим-график-кумулятивного-среднего-чека-по-группам.-Сделаем-выводы-и-предположения." data-toc-modified-id="Построим-график-кумулятивного-среднего-чека-по-группам.-Сделаем-выводы-и-предположения.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Построим график кумулятивного среднего чека по группам. Сделаем выводы и предположения.</a></span></li><li><span><a href="#Построим-график-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A.-Сделаем-выводы-и-предположения." data-toc-modified-id="Построим-график-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A.-Сделаем-выводы-и-предположения.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Построим график относительного изменения кумулятивного среднего чека группы B к группе A. Сделаем выводы и предположения.</a></span></li><li><span><a href="#Построим-график-кумулятивного-среднего-количества-заказов-на-посетителя-по-группам.-Сделаем-выводы-и-предположения." data-toc-modified-id="Построим-график-кумулятивного-среднего-количества-заказов-на-посетителя-по-группам.-Сделаем-выводы-и-предположения.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Построим график кумулятивного среднего количества заказов на посетителя по группам. Сделаем выводы и предположения.</a></span></li><li><span><a href="#Построим-график-относительного-изменения-кумулятивного-среднего-количества-заказов-на-посетителя-группы-B-к-группе-A.--Сделаем-выводы-и-предположения." data-toc-modified-id="Построим-график-относительного-изменения-кумулятивного-среднего-количества-заказов-на-посетителя-группы-B-к-группе-A.--Сделаем-выводы-и-предположения.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Построим график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A.  Сделаем выводы и предположения.</a></span></li><li><span><a href="#Построим-точечный-график-количества-заказов-по-пользователям.-Сделаем-выводы-и-предположения." data-toc-modified-id="Построим-точечный-график-количества-заказов-по-пользователям.-Сделаем-выводы-и-предположения.-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Построим точечный график количества заказов по пользователям. Сделаем выводы и предположения.</a></span></li><li><span><a href="#Посчитаем-95-й-и-99-й-перцентили-количества-заказов-на-пользователя.-Необходимо-выбрать-границу-для-определения-аномальных-пользователей." data-toc-modified-id="Посчитаем-95-й-и-99-й-перцентили-количества-заказов-на-пользователя.-Необходимо-выбрать-границу-для-определения-аномальных-пользователей.-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Посчитаем 95-й и 99-й перцентили количества заказов на пользователя. Необходимо выбрать границу для определения аномальных пользователей.</a></span></li><li><span><a href="#Построим-точечный-график-стоимостей-заказов.-Сделаем-выводы-и-предположения." data-toc-modified-id="Построим-точечный-график-стоимостей-заказов.-Сделаем-выводы-и-предположения.-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Построим точечный график стоимостей заказов. Сделаем выводы и предположения.</a></span></li><li><span><a href="#Посчитаем-95-й-и-99-й-перцентили-стоимости-заказов.-Необходимо-выбрать-границу-для-определения-аномальных-заказов." data-toc-modified-id="Посчитаем-95-й-и-99-й-перцентили-стоимости-заказов.-Необходимо-выбрать-границу-для-определения-аномальных-заказов.-4.9"><span class="toc-item-num">4.9&nbsp;&nbsp;</span>Посчитаем 95-й и 99-й перцентили стоимости заказов. Необходимо выбрать границу для определения аномальных заказов.</a></span></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«сырым»-данным.---Сделаем-выводы-и-предположения." data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«сырым»-данным.---Сделаем-выводы-и-предположения.-4.10"><span class="toc-item-num">4.10&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным. - Сделаем выводы и предположения.</a></span></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным.-Сделаем-выводы-и-предположения." data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным.-Сделаем-выводы-и-предположения.-4.11"><span class="toc-item-num">4.11&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным. Сделаем выводы и предположения.</a></span></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«очищенным»-данным.-Сделаем-выводы-и-предположения." data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-среднем-количестве-заказов-на-посетителя-между-группами-по-«очищенным»-данным.-Сделаем-выводы-и-предположения.-4.12"><span class="toc-item-num">4.12&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным. Сделаем выводы и предположения.</a></span></li><li><span><a href="#Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным.-Сделаем-выводы-и-предположения." data-toc-modified-id="Посчитаем-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным.-Сделаем-выводы-и-предположения.-4.13"><span class="toc-item-num">4.13&nbsp;&nbsp;</span>Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Сделаем выводы и предположения.</a></span></li><li><span><a href="#Примем-решение-по-результатам-теста." data-toc-modified-id="Примем-решение-по-результатам-теста.-4.14"><span class="toc-item-num">4.14&nbsp;&nbsp;</span>Примем решение по результатам теста.</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Анализ гипотез крупного интернет магазина

# %% [markdown]
# Вместе с отделом маркетинга требуется подготовить список гипотез для увеличения выручки.
# Необходимо приоритизировать гипотезы, запустить A/B-тест и проанализировать результаты.
#
# **Цель исследования:**
# 1. Подготовить список гипотез для увеличения выручки
# 2. Приоритизировать гипотезы
# 3. Запустить A/B-тест и проанализировать результаты
#
# **Ход исследования:**
#
# Будут открыты и проанализировны имеющиеся данные, определено качество выборки, наличие дубликатов, ошибок. За тем, произведем расчет дополнительных параметров. Подготовим список гипотез, приоритизируем их. Запустим A/B-тест и сделаеем выводы.
#
# Разобьем анализ гипотез на две части:
# 1. Приоритизация гипотез.
# 2. Анализ A/B-теста.
#
# **Описание данных**
#
# ***Данные для первой части анализа (Приоритизация гипотез):***
#
#  * Файл ***hypothesis.csv.***:
#
# `Hypothesis` — краткое описание гипотезы;
#
# `Reach` — охват пользователей по 10-балльной шкале;
#
# `Impact` — влияние на пользователей по 10-балльной шкале;
#
# `Confidence` — уверенность в гипотезе по 10-балльной шкале;
#
# `Efforts` — затраты ресурсов на проверку гипотезы по 10-балльной шкале. Чем больше значение Efforts, тем дороже проверка гипотезы.
#
# В файле ***hypothesis.csv*** 9 гипотез по увеличению выручки интернет-магазина с указанными параметрами `Reach`, `Impact`, `Confidence`, `Effort`.
#
#
# *Задача:*
#
# - Необходимо применить фреймворк ICE для приоритизации гипотез. Требуется отсортировать их по убыванию приоритета.
# - Необходимо применить фреймворк RICE для приоритизации гипотез. Требуется отсортировать их по убыванию приоритета.
# - Следует указать, как изменилась приоритизация гипотез при применении RICE вместо ICE; почему так произошло
#
#
# ***Данные для второй части анализа (Анализ A/B-теста):***
#
#  * Файл ***orders.csv.***:
#
# `transactionId` — идентификатор заказа;
#
# `visitorId` — идентификатор пользователя, совершившего заказ;
#
# `date` — дата, когда был совершён заказ;
#
# `revenue` — выручка заказа;
#
# `group` — группа A/B-теста, в которую попал заказ.
#
#  * Файл ***visitors.csv.*** :
#
# `date` — дата;
#
# `group` — группа A/B-теста;
#
# `visitors` — количество пользователей в указанную дату в указанной группе A/B-теста
#
#
# Мы провели A/B-тест и получили результаты, которые описаны в файлах orders.csv и visitors.csv.
#
# *Задача:*
#
# Проанализировать A/B-тест:
# - Необходимо построить график кумулятивной выручки по группам. Требуется сделать выводы и предположения.
# - Необходимо построить график кумулятивного среднего чека по группам. Требуется сделать выводы и предположения.
# - Необходимо построить график относительного изменения кумулятивного среднего чека группы B к группе A. Требуется сделать выводы и предположения.
# - Необходимо построить график кумулятивного среднего количества заказов на посетителя по группам. Требуется сделать выводы и предположения.
# - Необходимо построить график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A. - Требуется сделать выводы и предположения.
# - Необходимо построить точечный график количества заказов по пользователям. Требуется сделать выводы и предположения.
# - Следует посчитать 95-й и 99-й перцентили количества заказов на пользователя. Необходимо выбрать границу для определения аномальных пользователей.
# - Необходимо построить точечный график стоимостей заказов. Требуется сделать выводы и предположения.
# - Следует посчитать 95-й и 99-й перцентили стоимости заказов. Необходимо выбрать границу для определения аномальных заказов.
# - Следует посчитать статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным. - Требуется сделать выводы и предположения.
# - Следует посчитать статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным. Требуется сделать выводы и предположения.
# - Следует посчитать статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным. Требуется сделать выводы и предположения.
# - Следует посчитать статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Требуется сделать выводы и предположения.
# - Требуется принять решение по результатам теста и объяснить его. Варианты решений:
#   1. Остановить тест, зафиксировать победу одной из групп.
#   2. Остановить тест, зафиксировать отсутствие различий между группами.
#   3. Продолжить тест.

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# Импортируем необходимые библиотеки

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
from math import sqrt, factorial, exp
from scipy.stats import poisson,binom
from scipy import stats as st
from IPython.display import display, Markdown
from matplotlib.ticker import MaxNLocator

# %% [markdown]
# Откроем файлы и выведем исходник таблицы на экран для изучения.

# %%
hypothesis = pd.read_csv('/Volumes/Vika/Analize_new_proffesion/Для гит хаба/for_git_hab/исх/hypothesis.csv') 
orders = pd.read_csv('/Volumes/Vika/Analize_new_proffesion/Для гит хаба/for_git_hab/исх/orders.csv', parse_dates=['date']) 
visitors =  pd.read_csv('/Volumes/Vika/Analize_new_proffesion/Для гит хаба/for_git_hab/исх/visitors.csv', parse_dates=['date'])

# %% [markdown]
# Выведем на экран общую информацию о таблице **`hypothesis`** с помощью метода  ***info()*** и саму таблицу.

# %%
hypothesis.info()
# Установите максимальную ширину столбца для отображения
pd.set_option('display.max_colwidth', 200)
hypothesis
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Hypothesis  9 non-null      object
#  1   Reach       9 non-null      int64
#  2   Impact      9 non-null      int64
#  3   Confidence  9 non-null      int64
#  4   Efforts     9 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 492.0+ bytes
#                                                                                                      Hypothesis  \
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# ...

# %% [markdown]
# Типы данных в столбцах корректны, пропусков нет, для соблюдения устоявшихся норм(нижнего регистра), можем переименовать столбцы.

# %% [markdown]
# Выведем на экран общую информацию о таблице **`orders`** с помощью метода  ***info()*** и саму таблицу.

# %%
orders.info()
orders.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionId  1197 non-null   int64
#  1   visitorId      1197 non-null   int64
#  2   date           1197 non-null   datetime64[ns]
#  3   revenue        1197 non-null   int64
#  4   group          1197 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 46.9+ KB
#    transactionId   visitorId       date  revenue group
# 0     3667963787  3312258926 2019-08-15     1650     B
# 1     2804400009  3642806036 2019-08-15      730     B
# 2     2961555356  4069496402 2019-08-15      400     A
# 3     3797467345  1196621759 2019-08-15     9759     B
# 4     2282983706  2322279887 2019-08-15     2308     B

# %% [markdown]
# Типы данных в столбцах таблицы корректны, пропусков нет.

# %% [markdown]
# Выведем на экран общую информацию о таблице **`visitors`** с помощью метода  ***info()*** и саму таблицу.

# %%
visitors.info()
visitors.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      62 non-null     datetime64[ns]
#  1   group     62 non-null     object
#  2   visitors  62 non-null     int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 1.6+ KB
#         date group  visitors
# 0 2019-08-01     A       719
# 1 2019-08-02     A       619
# 2 2019-08-03     A       507
# 3 2019-08-04     A       717
# 4 2019-08-05     A       756

# %% [markdown]
# Типы данных в столбцах таблицы корректны, пропусков нет.

# %% [markdown]
# ## Предобработка данных
#
# ### Изменение типа данных
#
# Так как в таблицах типы данных во всех столбцах корректны - изменять их не требуется
#
# ### Поиск дубликатов
#
# Исходя из данных выше таблиц, имеет смысл проверить их на наличие явных дубликатов

# %%
print("Количество явных дубликатов в hypothesis:", hypothesis.duplicated().sum())
print("Количество явных дубликатов в orders:", orders.duplicated().sum())
print("Количество явных дубликатов в visitors:", visitors.duplicated().sum())
# Out:
# Количество явных дубликатов в hypothesis: 0
# Количество явных дубликатов в orders: 0
# Количество явных дубликатов в visitors: 0

# %% [markdown]
# Явных дубликатов нет.
#
# Переименуем столбцы, в которых не соблюден нижний регистр.

# %%
hypothesis.columns = ['hypothesis','reach','impact','confidence','efforts']
orders.columns = ['transaction_id','visitor_id','date','revenue','group']

# %% [markdown]
# В данном разделе таблицы были загружены и рассмотрены данные для анализа. Таблицы были проверены на пропуски, на соответствие типов данных в столбцах, так же была произведена проверка на наличие явных дубликатов.

# %% [markdown]
# ## Приоритизация гипотез.

# %% [markdown]
# Чтобы не тратить ресурсы на неважные и несрочные гипотезы, необходимо их приоритизировать. Для этого используются различные методы:
#
# * ***Матрица Эйзенхауэра*** - гипотезы делятся на 4 типа: Неважные/несрочные, важные/несрочные, неважные/срочные, важные/срочные. Тестированию подлежат важные/срочные гипотезы. Срочные, но неважные гипотезы — скорее всего, приведут к результатам лишь в краткосрочной перспективе и не повлияют на долгосрочные цели бизнеса соотвтетственно и тестироваться врядли будут.
#
#
# * ***WSJF*** - метод приоритизации, который позволяет оценить задачи более детально. Находится как отношение «цены промедления» к «длительности работы» по проверке гипотезы
#
#   Цена промедления складывается из следующих параметров:
#    - «клиент-бизнес ценность» — насколько улучшим пользовательскую или бизнес-метрику, если гипотеза корректна;
#    - «временная критичность» — насколько срочно нужно протестировать гипотезу;
#    - «уменьшение риска/реализация возможностей» — насколько проверка гипотезы позволит избежать серьёзных рисков или открыть новые бизнес-возможности.
#
#
#
# * ***ICE***  — отношение произведения Влияния и Уверенности к Усилиям ((Влияние x Уверенность)/Усилия)
#
#    - Влияние (Impact) — насколько сильно изменение повлияет на пользователей, их опыт и удовлетворение от продукта;
#    - Уверенность (Confidence) — насколько вы уверены, что это изменение повлияет на пользователей именно так;
#    - Усилия (Efforts) — сколько стоит протестировать эту гипотезу.
#
#
#
# * ***RICE*** - похож на ICE, но включает параметр Охват(Reach)((Влияние x Уверенность х Охват)/Усилия)
#
#   - Охват (Reach) — скольких пользователей затронет изменение, которое вы хотите внести;
#   - Влияние (Impact) — насколько сильно изменение повлияет на пользователей, их опыт и удовлетворение от продукта;
#   - Уверенность (Confidence) — насколько вы уверены, что это изменение повлияет на пользователей именно так;
#   - Усилия (Efforts) — сколько стоит протестировать эту гипотезу.
#
# Воспользуемся фреймворками ICE и RICE для приоритизации гипотез

# %% [markdown]
# ### Применение фреймворка ICE для приоритизации гипотез. Сортировка их по убыванию приоритета.

# %%
hypothesis['ICE'] = hypothesis['impact']*hypothesis['confidence']/hypothesis['efforts']

display(hypothesis.loc[:,['hypothesis','ICE']].sort_values('ICE',ascending=False))
# Out:
#                                                                                                      hypothesis  \
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# ...

# %% [markdown]
# После применения фреймворка ICE мы видим, что наиболее приорететной из всех является девятая гипотеза:
#
# ***Запустить акцию, дающую скидку на товар в день рождения,(ICE = 16.2)***
#
# На втором и третьем месте первая и восьмая соответственно:
#
# ***Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей,(ICE = 13.33)***;
#
# ***Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок,(ICE = 11.2)***

# %% [markdown]
# ### Применение фреймворка RICE для приоритизации гипотез. Сортировка их по убыванию приоритета.

# %%
hypothesis['RICE'] = hypothesis['reach']*hypothesis['impact']*hypothesis['confidence']/hypothesis['efforts']

display(hypothesis.loc[:,['hypothesis','RICE']].sort_values('RICE',ascending=False))
# Out:
#                                                                                                      hypothesis  \
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# ...

# %% [markdown]
# После применения фреймворка RICE мы видим, что наиболее приорететной из всех теперь стала восьмая гипотеза:
#
# ***Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок,(RICE = 112)***
#
# На второе и третье место попали третья, первая и седьмая гипотезы соответственно:
#
# ***Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа,(RICE = 56)***;
#
# ***Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей,(RICE = 40)***;
#
# ***Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию,(RICE = 40)***

# %% [markdown]
# ### Разница в приоритизации гипотез при применении RICE вместо ICE. Причины различия результатов.

# %% [markdown]
# Мы видим как сильно отличаются результаты применения фреймворка RICE от ICE. Иные результы получились по причине того, что фреймворк RICE, в отличии от ICE учитывает охват пользователей.
#
# Так очевидно, что у гипотезы 9, которая лидировала по приоритету после применения фреймворка ICE охват равен 1(минимальный по 10-и бальной шкале), так как величина ICE и RICE у нее оказались равны.
#
# При этом гипотеза под номером 8, имея максимальную величину охвата, вырвалась с третьего места на первое.

# %% [markdown]
# **Вывод по разделу**
#
# Недооценивать скольких пользователей затронет изменение, которое мы собираемся вносить нельзя, поэтому по итогу применения обоих фреймворков можно сказать, что гипотеза 8 наиболее приоритетна. А на втором месте можно оставить гипотезу 1, так как уровни и ICE и RICE у нее высокие.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Хорошая работа, корректно применены фреймворки и проанализированы полученные результаты.
#
#
# Еще результаты можно было бы объединить в единой таблице для наглядности. Также их можно было бы проранжировать и выделить цветом: https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html
#
# А в качестве визуализации изменения приоритетов можно использовать: <a href="https://datayoga.ru/tpost/zh3s62fori-sloupgraf">slope graph</a>, <a href="https://cduvallet.github.io/posts/2018/03/slopegraphs-in-python">slope graph 2</a>, <a href="https://chart-studio.plotly.com/~pcchang/224/slopegraph-spending-and-academic-performance-by-states-doc/#/">реализация на plotly</a>
#
# </div>

# %% [markdown]
# ## Анализ A/B-теста

# %% [markdown]
# ### Построим график кумулятивной выручки по группам. Сделаем выводы и предположения.
#
# Для анализа будут использованы данные из таблиц.
# Взглянем на эти таблицы еще раз

# %%
print("Таблица orders")
display(orders.head())
print()
print("Таблица visitors")
display(visitors.head())
# Out:
# Таблица orders
#    transaction_id  visitor_id       date  revenue group
# 0      3667963787  3312258926 2019-08-15     1650     B
# 1      2804400009  3642806036 2019-08-15      730     B
# 2      2961555356  4069496402 2019-08-15      400     A
# 3      3797467345  1196621759 2019-08-15     9759     B
# 4      2282983706  2322279887 2019-08-15     2308     B
# Таблица visitors
#         date group  visitors
# 0 2019-08-01     A       719
# 1 2019-08-02     A       619
# 2 2019-08-03     A       507
# 3 2019-08-04     A       717
# 4 2019-08-05     A       756

# %% [markdown]
# Проверим количество пользователей, которые оказались и в группе А, и в группе В.
#
# Определим количество пользователей попавших в обе группы в таблице `orders`

# %%
orders_2groups = orders.groupby('visitor_id').agg({'group' : 'nunique'}).query('group > 1').reset_index()
display(Markdown(
f"Количество пользователей, попавших в обе группы - {orders_2groups['visitor_id'].count()}"))
# Out:
# Количество пользователей, попавших в обе группы - 58

# %% [markdown]
# Таким образом, 58 пользователей находятся и в группе А и в группе В.
#
# Проверим, какое это количество от общего числа.

# %%
display(Markdown(
f"От общего числа \
{round((orders_2groups['visitor_id'].count())/orders['visitor_id'].nunique()*100,2)}%"))
# Out:
# От общего числа 5.63%

# %% [markdown]
# Удалим пользователей, состоящих в обоих группах.

# %%
orders_filtered = orders[~orders['visitor_id'].isin(orders_2groups['visitor_id'])]

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#    ✔️ Здорово, что проверяем пересечение групп! Наличие пользователей попавших в обе группы сильно влияет на результаты теста. Если таких пользователей не много - лучше их удалить.
# </div>

# %% [markdown]
# Теперь можем приступить к дальнейшему анализу.
#
# Соберём агрегированные кумулятивные по дням данные о заказах в несколько действий.

# %%
# создаем массив уникальных пар значений дат и групп теста
dates_groups = orders_filtered[['date','group']].drop_duplicates()

orders_aggregated = (dates_groups
                     .apply(lambda x: orders_filtered[np.logical_and(orders_filtered['date'] <= x['date'],
                                                                     orders_filtered['group'] == x['group'])]\
                     .agg({'date' : 'max',
                           'group' : 'max',
                           'transaction_id' : 'nunique',
                           'visitor_id' : 'nunique',
                           'revenue' : 'sum'}), axis=1)
                     .sort_values(by=['date','group']))

# %% [markdown]
# Аналогично получим агрегированные кумулятивные по дням данные о посетителях интернет-магазина.

# %%
visitors_aggregated = (dates_groups
                       .apply(lambda x: visitors[np.logical_and(visitors['date'] <= x['date'],
                                                                         visitors['group'] == x['group'])]
                       .agg({'date' : 'max',
                             'group' : 'max',
                             'visitors' : 'sum'}), axis=1)
                       .sort_values(by=['date','group']))

# %%
# объединяем кумулятивные данные в одной таблице
cumulative_data = orders_aggregated.merge(visitors_aggregated,
                                          left_on=['date', 'group'],
                                          right_on=['date', 'group'])
cumulative_data.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

display(cumulative_data.head(5))
# Out:
#         date group  orders  buyers  revenue  visitors
# 0 2019-08-01     A      23      19   142779       719
# 1 2019-08-01     B      17      17    59758       713
# 2 2019-08-02     A      42      36   234381      1338
# 3 2019-08-02     B      40      39   221801      1294
# 4 2019-08-03     A      66      60   346854      1845

# %%
# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе А
cumulative_revenue_a = cumulative_data[cumulative_data['group']=='A'][['date','revenue', 'orders']]

# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе B
cumulative_revenue_b = cumulative_data[cumulative_data['group']=='B'][['date','revenue', 'orders']]

# Строим график выручки группы А
plt.figure(figsize=(10, 6))
plt.plot(cumulative_revenue_a['date'], cumulative_revenue_a['revenue'], label='A')

# Строим график выручки группы B
plt.plot(cumulative_revenue_b['date'], cumulative_revenue_b['revenue'], label='B')
# Добавляем заголовок
plt.title('График кумулятивной выручки по группам')
# Добавляем подпись оси X и Y
plt.xlabel('даты')
plt.ylabel('выручка, у.е.')
plt.legend()
plt.xticks(rotation=50)
plt.grid(True)
plt.show()

# %% [markdown]
# График иллюстрирует, что обе группы показывают рост кумулятивной выручки в течение всего теста. *Это может быть признаком того, что обе группы продолжают привлекать клиентов и увеличивать продажи с течением времени.*
#
# Так же мы видим, что в начале теста выручка и у группы А и у группы В была почти на одном уровне. Начиная с 2019-08-05 группа B опередила группу А и далее в большинстве точек графика показывает более высокую кумулятивную выручку, чем группа A. *Это может указывать на то, что вариант, представленный в группе B, более эффективен с точки зрения генерации дохода.*
#
# Заметен резкий скачок у группы B, что *может указывать на ряд вещей, например, на крупную покупку или заказы, изменение цен или увеличение числа заказов.* Важно проанализировать данные на предмет аномалий или выбросов, которые могут повлиять на результаты.
#
# Группа A показывает более плавный и стабильный рост без резких скачков, что может указывать на более равномерное увеличение продаж без аномальных всплесков.
#
# Делать однозначные выводы рано. Потребуется более глубокий анализ. Например, следует рассмотреть средний чек, конверсию и количество заказов, чтобы лучше понять причины различий в выручке. А чтобы сделать обоснованные выводы о том, действительно ли одна группа лучше другой, необходимо провести статистический тест, чтобы определить, являются ли различия статистически значимыми.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ График построен верно и можем зафиксировать аномалию в группе В.
# </div>

# %% [markdown]
# ### Построим график кумулятивного среднего чека по группам. Сделаем выводы и предположения.

# %%
plt.figure(figsize=(10, 6))
plt.plot(cumulative_revenue_a['date'], cumulative_revenue_a['revenue']/cumulative_revenue_a['orders'],
         label='A')
plt.plot(cumulative_revenue_b['date'], cumulative_revenue_b['revenue']/cumulative_revenue_b['orders'],
         label='B')
plt.legend()
# Добавляем заголовок
plt.title('График кумулятивного среднего чека по группам')
# Добавляем подпись оси X и Y
plt.xlabel('даты')
plt.ylabel('средний чек, у.е.')
plt.legend()
plt.xticks(rotation=50)
plt.grid(True)
plt.show()

# %% [markdown]
# Группа B имеет более высокий средний чек. После определенной точки на графике(2019-08-17) группа B демонстрирует значительное увеличение среднего чека по сравнению с группой A. *Это может указывать на более эффективную стратегию применяемую к группе или наличие более крупных заказов в группе B*.
#
# При этом острый пик в группе B может быть результатом аномально крупных заказов или выбросов. Такие резкие изменения могут исказить общую картину, и их следует проверить дополнительно.
#
# Группа A показывает более плавный и стабильный рост без резких скачков, что может говорить о более предсказуемом и равномерном потребительском поведении в этой группе.
#
# Один график не позволяет сделать окончательные выводы о статистической значимости различий в среднем чеке между группами. Для этого потребуется проведение статистического теста.
#
# **Если подтвердится, что увеличение среднего чека в группе B не связано с выбросами и статистически значимо, это может указывать на более высокую прибыльность изменений, внедренных для группы B.**

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Да, тут так-же группа В выделяется.
# </div>

# %% [markdown]
# ### Построим график относительного изменения кумулятивного среднего чека группы B к группе A. Сделаем выводы и предположения.

# %%
# собираем данные в одном датафрейме
merged_cumulative_revenue = cumulative_revenue_a.merge(cumulative_revenue_b,
                                                     left_on='date',
                                                     right_on='date',
                                                     how='left',
                                                     suffixes=['a', 'b'])

# cтроим отношение средних чеков
plt.figure(figsize=(10, 6))
plt.plot(merged_cumulative_revenue['date'],
         (merged_cumulative_revenue['revenueb']/merged_cumulative_revenue['ordersb'])/
         (merged_cumulative_revenue['revenuea']/merged_cumulative_revenue['ordersa'])-1)

# добавляем ось X
plt.axhline(y=0, color='black', linestyle='--')
# Добавляем заголовок
plt.title('График относительного изменения кумулятивного среднего чека группы B к группе A')
plt.xlabel('даты')
plt.ylabel('средний чек, у.е.')
plt.xticks(rotation=50)
plt.grid(True)
plt.show()

# %% [markdown]
# График показывает, что относительные изменения в среднем чеке колеблются в течение всего периода, что *указывает на нестабильность и возможное наличие аномальных данных или выбросов, особенно если эти колебания крупные.*
#
# На графике видно, что в определенные даты происходят значительные изменения в среднем чеке группы B по сравнению с группой A. *Это может быть связано с крупными заказами или изменениями в поведении покупателей группы B.*
#
# Нет устойчивого тренда к увеличению или уменьшению относительного различия, что затрудняет делать окончательные выводы о том, как группа B отличается от группы A с точки зрения среднего чека.
#
# Поскольку график пересекает нулевую отметку, это говорит о том, что были моменты, когда средний чек группы В был ниже, чем у группы А. Однако, более длительный промежуток времени средний чек группы В выше, чем у группы А.
#
# Необходимость дополнительного анализа: Чтобы понять причины таких изменений, следует провести дополнительный анализ. Например, следует произвести анализ среднего количества заказов, чтобы увидеть, как изменялось количество заказов по группам

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Верно, похоже на крупные заказы.
# </div>

# %% [markdown]
# ### Построим график кумулятивного среднего количества заказов на посетителя по группам. Сделаем выводы и предположения.

# %%
# считаем среднее количество заказов на посетителя
cumulative_data['conversion'] = cumulative_data['orders']/cumulative_data['visitors']

# отделяем данные по группе A
cumulative_data_a = cumulative_data[cumulative_data['group']=='A']

# отделяем данные по группе B
cumulative_data_b = cumulative_data[cumulative_data['group']=='B']

# строим графики
plt.figure(figsize=(10, 6))
plt.plot(cumulative_data_a['date'], cumulative_data_a['conversion'], label='A')
plt.plot(cumulative_data_b['date'], cumulative_data_b['conversion'], label='B')
plt.legend()

# задаем масштаб осей
#plt.axis(["2019-08-01", '2019-09-01', 0, 0.5])
plt.title('График кумулятивного среднего количества заказов на посетителя по группам')
plt.xlabel('даты')
plt.ylabel('среднее кол-во заказов, ед.')
plt.xticks(rotation=50)
plt.grid(True)
plt.show()

# %% [markdown]
# В начале теста есть значительные колебания в обеих группах. Это может быть связано с недостаточным количеством данных (поскольку кумулятивные метрики особенно чувствительны к начальным изменениям) или с аномальными заказами, которые существенно влияют на среднее значение.
#
# После первоначальных колебаний данные обеих групп стабилизируются, что может указывать на достижение статистического равновесия по мере накопления данных.
#
# Группа A показывает более низкое среднее количество заказов на посетителя по сравнению с группой B на протяжении большей части теста. ***Это может означать, что изменения, протестированные в группе A, были менее эффективны в плане стимулирования большего количества заказов на одного посетителя.***
#
# Группа B демонстрирует более высокий показатель по сравнению с группой A. ***Это может говорить о том, что изменения, протестированные в группе B, привели к увеличению количества заказов на посетителя.***
#
# Следует отметить, что несмотря на общую тенденцию группы B к более высокому среднему количеству заказов, наблюдаются колебания, которые стоит дополнительно исследовать на предмет возможных аномалий.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Согласен, группа В в лидерах.
# </div>

# %% [markdown]
# ### Построим график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A.  Сделаем выводы и предположения.

# %%
merged_cumulative_conversions = (cumulative_data_a[['date','conversion']]
                                 .merge(cumulative_data_b[['date','conversion']],
                                        left_on='date',
                                        right_on='date',
                                        how='left',
                                        suffixes=['_a', '_b']))
plt.figure(figsize=(10, 6))
(plt.plot(merged_cumulative_conversions['date'],
          merged_cumulative_conversions['conversion_b']/merged_cumulative_conversions['conversion_a']-1,
label="Относительный прирост кумулятивного среднего количества заказов \n\
на посетителя группы B относительно группы A"))
plt.legend()

plt.axhline(y=0, color='black', linestyle='--')
plt.axhline(y=-0.1, color='grey', linestyle='--')
plt.title('График относительного прироста кумулятивного среднего количества заказов \n\
на посетителя группы B относительно группы A')
plt.xlabel('даты')
plt.ylabel('среднее кол-во заказов, ед.')
plt.xticks(rotation=50)
plt.grid(True)
plt.show()

# %% [markdown]
# На графике видно, что вначале теста группа B сильно проигрывала группе А, однако график показывает положительный относительный прирост у группы В по сравнению с группой A, *что может указывать на более высокую эффективность изменений, внедренных в группе B.*
#
# В конце представленного периода наблюдается тенденция к увеличению относительного прироста для группы B. *Это может свидетельствовать о накопительном эффекте изменений, которые были проведены в группе B.*
#
# Теперь посмотрим на точечный график количества заказов по пользователям.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Да, группа В выше, а еще в последней трети эксперимента наблюдается стабилизация результатов.
# </div>

# %% [markdown]
# ### Построим точечный график количества заказов по пользователям. Сделаем выводы и предположения.

# %%
orders_by_users = (
    orders_filtered.groupby('visitor_id', as_index=False)
    .agg({'transaction_id': 'nunique'})
)

orders_by_users.columns = ['buyers', 'orders']

display(orders_by_users.sort_values(by='orders', ascending=False).head(10))

display(Markdown(
f"Видим из таблицы, что максимальное количество заказов у пользователей - 3."))

plt.figure(figsize=(10, 6))
plt.hist(orders_by_users['orders'], bins=3)
plt.title('Гистограмма распределения количества заказов по пользователям')
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
plt.xlabel('кол-во')
plt.grid(True)
plt.show()

display(Markdown(
f"Гистограмма распределения количества заказов по пользователям наглядно иллюстрирует, \
что чаще пльзователь делает только один заказ."))
# Out:
#          buyers  orders
# 687  2988190573       3
# 632  2742574263       3
# 908  3967698036       3
# 890  3908431265       3
# 138   611059232       3
# 55    249864742       3
# 478  2108163459       3
# 407  1772171838       2
# 380  1637811943       2
# 375  1617417821       2
# Видим из таблицы, что максимальное количество заказов у пользователей - 3.
# Гистограмма распределения количества заказов по пользователям наглядно иллюстрирует, что чаще пльзователь делает только один заказ.

# %%
x_values = pd.Series(range(0,len(orders_by_users)))
plt.figure(figsize=(10, 6))
plt.scatter(x_values, orders_by_users['orders'])
plt.gca().yaxis.set_major_locator(MaxNLocator(integer=True))
plt.title('Точечный график количества заказов')
plt.ylabel('кол-во')
plt.grid(True)
plt.show()

display(Markdown(
f"Точечный график количества заказов по пользователям показывает, \
что пользователей, которые делают два и три заказа очень мало. Но точная их доля пока нам не ясна,\
 поэтому посчитаем 95-й и 99-й перцентили."))
# Out:
# Точечный график количества заказов по пользователям показывает, что пользователей, которые делают два и три заказа очень мало. Но точная их доля пока нам не ясна, поэтому посчитаем 95-й и 99-й перцентили.

# %% [markdown]
# ### Посчитаем 95-й и 99-й перцентили количества заказов на пользователя. Необходимо выбрать границу для определения аномальных пользователей.

# %%
print(np.percentile(orders_by_users['orders'], [95, 99])) 

display(Markdown(
f" Таким образом, мы видим, что не более 5% пользователей оформляли больше чем 1 заказ и только \
один и менее процентов пользователей оформляли больше чем 2 заказа.\n\n\
Будет разумно выбрать 1 заказ на одного пользователя за верхнюю границу числа заказов, и отсеять \
аномальных пользователей по ней."))
# Out:
# [1. 2.]
#  Таким образом, мы видим, что не более 5% пользователей оформляли больше чем 1 заказ и только один и менее процентов пользователей оформляли больше чем 2 заказа.
#
# Будет разумно выбрать 1 заказ на одного пользователя за верхнюю границу числа заказов, и отсеять аномальных пользователей по ней.

# %% [markdown]
# ### Построим точечный график стоимостей заказов. Сделаем выводы и предположения.

# %%
display(orders_filtered.sort_values(by='revenue', ascending=False).head(10))

display(Markdown(
f"Видим из таблицы, что максимальная стоимость заказа - 1 294 500. При этом следующая по величине цена - 202 740\
, что значительно ниже. Очень похоже на то, что закралась какая-то ошибка. Построим гистограмму распределения."))

plt.figure(figsize=(15, 6))
plt.hist(orders_filtered['revenue'], bins=50)
plt.title('Гистограмма распределения стоимостей заказов')
plt.xlabel('стоимость')
plt.grid(True)
plt.show()

display(Markdown(
f"Гистограмма распределения стоимостей заказов наглядно иллюстрирует, \
что чаще стоимость заказа варьируется от 0 и до примерно 50 тыс условных единиц. Для определения количества вбросов\
построим точечный график стоимости заказа."))
# Out:
#       transaction_id  visitor_id       date  revenue group
# 425        590470918  1920142716 2019-08-19  1294500     B
# 1196      3936777065  2108080724 2019-08-15   202740     B
# 1136       666610489  1307669133 2019-08-13    92550     A
# 744       3668308183   888512513 2019-08-27    86620     B
# 743       3603576309  4133034833 2019-08-09    67990     A
# 1103      1348774318  1164614297 2019-08-12    66350     A
# 1099       316924019   148427295 2019-08-12    65710     A
# 949       1347999392   887908475 2019-08-21    60450     A
# 940       2420050534  4003628586 2019-08-08    58550     B
# 131       3163614039  2254586615 2019-08-22    53904     A
# Видим из таблицы, что максимальная стоимость заказа - 1 294 500. При этом следующая по величине цена - 202 740, что значительно ниже. Очень похоже на то, что закралась какая-то ошибка. Построим гистограмму распределения.
# ...

# %%
x_values = pd.Series(range(0,len(orders_filtered)))
plt.figure(figsize=(10, 6))
plt.scatter(x_values, orders_filtered['revenue'])
plt.title('Точечный график стоимостей заказов')
plt.ylabel('стоимость')
plt.grid(True)
plt.show()

display(Markdown(
f"Точечный график стоимостей заказов иллюстрирует то, что имеется два вброса - 1,2 млн и 0,2 млн. Однако, стоит \
посчитать 95-й и 99-й перцентили, чтобы понять какое ограничение по стоимости заказов имеет смысл сделать."))
# Out:
# Точечный график стоимостей заказов иллюстрирует то, что имеется два вброса - 1,2 млн и 0,2 млн. Однако, стоит посчитать 95-й и 99-й перцентили, чтобы понять какое ограничение по стоимости заказов имеет смысл сделать.

# %% [markdown]
# ### Посчитаем 95-й и 99-й перцентили стоимости заказов. Необходимо выбрать границу для определения аномальных заказов.

# %%
print(np.percentile(orders_filtered['revenue'], [95, 99])) 

display(Markdown(
f" 95 перцентиль равен {np.percentile(orders_filtered['revenue'], 95)} у.е. то есть, не более 5% пользователей \
оформляли  заказ на сумму не более чем на 26 785у.е., а так как 99 перцентиль равен\
 {np.percentile(orders_filtered['revenue'], 99)}у.е. - один и менее процентов пользователей оформляли заказ на \
 сумму более чем 53 904 у.е.\n\n\
Будет разумно выбрать 27 тыс за верхнюю границу суммы заказов, и отсеять аномальных пользователей по ней."))
# Out:
# [26785. 53904.]
#  95 перцентиль равен 26785.0 у.е. то есть, не более 5% пользователей оформляли  заказ на сумму не более чем на 26 785у.е., а так как 99 перцентиль равен 53904.0у.е. - один и менее процентов пользователей оформляли заказ на  сумму более чем 53 904 у.е.
#
# Будет разумно выбрать 27 тыс за верхнюю границу суммы заказов, и отсеять аномальных пользователей по ней.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️ Перцентали выбраны верно.
# </div>

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным. - Сделаем выводы и предположения.

# %% [markdown]
# ***Сформулируем следующие гипотезы:***
#
# - H0 - Нет различий между средним количеством заказов на посетителя между группами А и В
# - H1 - Есть различия между средним количеством заказов на посетителя между группами А и В
#
# Теперь проверим эти гипотезы.
# За критический уровень статистической значимости возьмем 5%.

# %%
#Определим количество пользователей в выбранную дату в группе A
visitors_a_daily = visitors[visitors['group'] == 'A'][['date', 'visitors']]
visitors_a_daily.columns = ['date', 'visitors_per_date_a']

#Определим количество пользователей до выбранной даты включительно в группе А
visitors_a_cummulative = visitors_a_daily.apply(
    lambda x: visitors_a_daily[visitors_a_daily['date'] <= x['date']].agg(
        {'date': 'max', 'visitors_per_date_a': 'sum'}
    ),
    axis=1,
)
visitors_a_cummulative.columns = ['date', 'visitors_cummulative_a']

#Определим количество пользователей в выбранную дату в группе В
visitors_b_daily = visitors[visitors['group'] == 'B'][['date', 'visitors']]
visitors_b_daily.columns = ['date', 'visitors_per_date_b']

#Определим количество пользователей до выбранной даты включительно в группе B
visitors_b_cummulative = visitors_b_daily.apply(
    lambda x: visitors_b_daily[visitors_b_daily['date'] <= x['date']].agg(
        {'date': 'max', 'visitors_per_date_b': 'sum'}
    ),
    axis=1,
)
visitors_b_cummulative.columns = ['date', 'visitors_cummulative_b']

# Определим количество заказов и суммарную выручку в выбранную дату в группе A
orders_a_daily = (
    orders_filtered[orders_filtered['group'] == 'A'][['date', 'transaction_id', 'visitor_id', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transaction_id': pd.Series.nunique, 'revenue': 'sum'})
)
orders_a_daily.columns = ['date', 'orders_per_date_a', 'revenue_per_date_a']

# Определим суммарное число заказов  и суммарную выручку до выбранной даты включительно в группе A
orders_a_cummulative = orders_a_daily.apply(
    lambda x: orders_a_daily[orders_a_daily['date'] <= x['date']].agg(
        {'date': 'max', 'orders_per_date_a': 'sum', 'revenue_per_date_a': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
orders_a_cummulative.columns = [
    'date',
    'orders_cummulative_a',
    'revenue_cummulative_a',
]

# Определим количество заказов и суммарную выручку в выбранную дату в группе B
orders_b_daily = (
    orders_filtered[orders_filtered['group'] == 'B'][['date', 'transaction_id', 'visitor_id', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transaction_id': pd.Series.nunique, 'revenue': 'sum'})
)
orders_b_daily.columns = ['date', 'orders_per_date_b', 'revenue_per_date_b']

# Определим суммарное число заказов и суммарную выручку до выбранной даты включительно в группе В
orders_b_cummulative = orders_b_daily.apply(
    lambda x: orders_b_daily[orders_b_daily['date'] <= x['date']].agg(
        {'date': 'max', 'orders_per_date_b': 'sum', 'revenue_per_date_b': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
orders_b_cummulative.columns = [
    'date',
    'orders_cummulative_b',
    'revenue_cummulative_b',
]

data = (
    orders_a_daily.merge(
        orders_b_daily, left_on='date', right_on='date', how='left'
    )
    .merge(orders_a_cummulative, left_on='date', right_on='date', how='left')
    .merge(orders_b_cummulative, left_on='date', right_on='date', how='left')
    .merge(visitors_a_daily, left_on='date', right_on='date', how='left')
    .merge(visitors_b_daily, left_on='date', right_on='date', how='left')
    .merge(visitors_a_cummulative, left_on='date', right_on='date', how='left')
    .merge(visitors_b_cummulative, left_on='date', right_on='date', how='left')
)

display(data.head(5))

# Посчитаем число совершённых заказов для пользователей, которые заказывали хотя бы 1 раз в группе А
orders_by_users_a = (
    orders_filtered[orders_filtered['group'] == 'A']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique})
)
orders_by_users_a.columns = ['user_id', 'orders']

# Посчитаем число совершённых заказов для пользователей, которые заказывали хотя бы 1 раз в группе В
orders_by_users_b = (
    orders_filtered[orders_filtered['group'] == 'B']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique})
)
orders_by_users_b.columns = ['user_id', 'orders']

# Объявим переменные sample_a и sample_в, в которых пользователям из разных групп будет соответствовать
# количество заказов.
sample_a = pd.concat(
    [
        orders_by_users_a['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitors_per_date_a'].sum() - len(orders_by_users_a['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sample_b = pd.concat(
    [
        orders_by_users_b['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitors_per_date_b'].sum() - len(orders_by_users_b['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

# p-value для сравнения среднего между группами
print("p-value для сравнения среднего между группами:","{0:.5f}".format(st.mannwhitneyu(sample_a, sample_b)[1]))

# относительное различие в среднем между группами
print("относительное различие в среднем между группами:","{0:.3f}".format(sample_b.mean() / sample_a.mean() - 1))
# Out:
#         date  orders_per_date_a  revenue_per_date_a  orders_per_date_b  \
# 0 2019-08-01                 23              142779                 17
# 1 2019-08-02                 19               91602                 23
# 2 2019-08-03                 24              112473                 14
# 3 2019-08-04                 11               41176                 14
# 4 2019-08-05                 22               86383                 21
#
#    revenue_per_date_b  orders_cummulative_a  revenue_cummulative_a  \
# 0               59758                    23                 142779
# 1              162043                    42                 234381
# 2               67049                    66                 346854
# 3               96890                    77                 388030
# 4               89908                    99                 474413
#
#    orders_cummulative_b  revenue_cummulative_b  visitors_per_date_a  \
# ...

# %% [markdown]
# Значение p-value меньше 0.05, потому нулевую гипотезу можно отвергнуть.
# Анализ «сырых данных» сообщает, что в среднем количестве заказов между группами есть статистически значимые различия. Относительный прирост среднего группы B к конверсии группы A равен 16%.
#
# Теперь проверим различия между группами в среднем чеке заказа.

# %% [markdown]
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Нулевая и альтернативная гипотезы сформулированы.
# </div>

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным. Сделаем выводы и предположения.

# %% [markdown]
# ***Сформулируем следующие гипотезы:***
#
# - H0 - Нет различий между средним чеком заказа между группами А и В
# - H1 - Есть различия между средним чеком заказа между группами А и В
#
# Теперь проверим эти гипотезы.
# За критический уровень статистической значимости возьмем 5%.

# %%
print("p-value для сравнения среднего между группами:",('{0:.3f}'.format(
    st.mannwhitneyu(orders_filtered[orders_filtered['group']=='A']['revenue'],
                       orders_filtered[orders_filtered['group']=='B']['revenue'])[1])))

print("относительное различие в среднем между группами:",('{0:.3f}'.format(
    orders_filtered[orders_filtered['group']=='B']['revenue'].mean()/
    orders_filtered[orders_filtered['group']=='A']['revenue'].mean()-1)))
# Out:
# p-value для сравнения среднего между группами: 0.829
# относительное различие в среднем между группами: 0.287

# %% [markdown]
# А вот со средним чеком иная ситуация: значение p-value значительно больше 0.05, отвергнуть нулевую гипотезу здесь мы не можем. Различия между группами в 29% не явлляется статистически значимым.
#
# Произведем анализ без аномальных значений.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Так вывод звучит корректней.
#
# Тут все просто. Раз теcт показал, что нет стат значимой разницы между группами - то каково бы различие чека не было, оно не будет являться стат. значимым (у нас тут выбросы дают большое различие чеков, но их всего несколько и на общее различие среднего чека по группам они не влияют)
# </div>

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным. Сделаем выводы и предположения.

# %% [markdown]
# Сделаем срезы пользователей с числом заказов больше 1(95-й перцентиль) — users_with_many_orders и пользователей, совершивших заказы дороже 27000 (95-й перцентиль)— users_with_expensive_orders.

# %%
revenue_lim = np.percentile(orders['revenue'], 95)
users_with_many_orders = pd.concat(
    [
        orders_by_users_a[orders_by_users_a['orders'] > 1]['user_id'],
        orders_by_users_b[orders_by_users_b['orders'] > 1]['user_id'],
    ],
    axis=0,
)
users_with_expensive_orders = orders_filtered[orders_filtered['revenue'] > revenue_lim]['visitor_id']
abnormal_users = (
    pd.concat([users_with_many_orders, users_with_expensive_orders], axis=0)
    .drop_duplicates()
    .sort_values()
)
display(abnormal_users.head(5))

print("Количество аномальных пользователей: ",abnormal_users.shape[0])
# Out:
# 1099    148427295
# 928     204675465
# 33      249864742
# 684     358944393
# 36      366673373
# dtype: int64
# Количество аномальных пользователей:  83

# %% [markdown]
# ***Вспомним проверяемые гипотезы:***
#
# - H0 - Нет различий между средним количеством заказов на посетителя между группами А и В
# - H1 - Есть различия между средним количеством заказов на посетителя между группами А и В
#
# Теперь проверим эти гипотезы.
# За критический уровень статистической значимости возьмем 5%.

# %% [markdown]
# Посчитаем статистическую значимость различия среднего количества заказов после удаления аномальных пользователей. Создадим переменные sample_a_filtered и sample_b_filtered, в которых сохраним очищенные данные о заказах.

# %%
sample_a_filtered = pd.concat(
    [
        orders_by_users_a[
            np.logical_not(orders_by_users_a['user_id'].isin(abnormal_users))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitors_per_date_a'].sum() - len(orders_by_users_a['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sample_b_filtered = pd.concat(
    [
        orders_by_users_b[
            np.logical_not(orders_by_users_b['user_id'].isin(abnormal_users))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitors_per_date_b'].sum() - len(orders_by_users_b['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

# p-value для сравнения среднего между группами
print("p-value для сравнения среднего между группами(без аномалий):",
      '{0:.5f}'.format(st.mannwhitneyu(sample_a_filtered, sample_b_filtered)[1]))

# относительное различие в среднем между группами
print("относительное различие в среднем между группами(без аномалий):",
      '{0:.3f}'.format(sample_b_filtered.mean()/sample_a_filtered.mean()-1))
# Out:
# p-value для сравнения среднего между группами(без аномалий): 0.01223
# относительное различие в среднем между группами(без аномалий): 0.181

# %% [markdown]
# Теперь значение p-value стало чуть больше, но по-прежнему менее 5%, а различия между группами увеличились на 1 процент- 17%.
#
# Можно сделать вывод, что нулевую гипотезу можно отвергнуть.
# Посмотрим, какие результаты будут получены после расчета статистической значимости различий в среднем чеке заказа.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера</b>
#
#   ✔️  И тут отвергаем нулевую гипотезу.
# </div>

# %% [markdown]
# ### Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Сделаем выводы и предположения.

# %% [markdown]
# ***Вспомним проверяемые гипотезы:***
#
# - H0 - Нет различий между средним чеком заказа между группами А и В
# - H1 - Есть различия между средним чеком заказа между группами А и В
#
# Теперь проверим эти гипотезы.
# За критический уровень статистической значимости возьмем 5%.

# %%
# p-value для сравнения среднего между группами
print("p-value для сравнения среднего между группами(без аномалий):",
    '{0:.5f}'.format(
        st.mannwhitneyu(
            orders_filtered[
                np.logical_and(
                    orders_filtered['group'] == 'A',
                    np.logical_not(orders_filtered['visitor_id'].isin(abnormal_users)),
                )
            ]['revenue'],
            orders_filtered[
                np.logical_and(
                    orders_filtered['group'] == 'B',
                    np.logical_not(orders_filtered['visitor_id'].isin(abnormal_users)),
                )
            ]['revenue'],
        )[1]
    )
)

# относительное различие в среднем между группами
print("относительное различие в среднем между группами(без аномалий):",
    "{0:.3f}".format(
        orders_filtered[
            np.logical_and(
                orders_filtered['group'] == 'B',
                np.logical_not(orders_filtered['visitor_id'].isin(abnormal_users)),
            )
        ]['revenue'].mean()
        / orders_filtered[
            np.logical_and(
                orders_filtered['group'] == 'A',
                np.logical_not(orders_filtered['visitor_id'].isin(abnormal_users)),
            )
        ]['revenue'].mean()
        - 1
    )
)
# Out:
# p-value для сравнения среднего между группами(без аномалий): 0.85100
# относительное различие в среднем между группами(без аномалий): -0.006

# %% [markdown]
# Значение p-value увеличилось с 83% до 85%, а относитльное различие уменьшилось до -0,006% и не является статистически значимым.
#
# Таким образом мы не можем отвергнуть нулевую гипотезу о том, что различия в среднем чеке между группами отсутствуют.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий ревьюера v.2</b>
#
#   ✔️ Верно!
# </div>

# %% [markdown]
# Выводы по разделу:
#
# * Анализ графика кумулятивной выручки по группам иллюстрирует, что в начале теста выручка и у группы А и у группы В была почти на одном уровне. Начиная с 2019-08-05 группа B опередила группу А и далее в большинстве точек графика показывает более высокую кумулятивную выручку, чем группа A. **Это может указывать на то, что вариант, представленный в группе B, более эффективен с точки зрения генерации дохода.**
#
#
# * График кумулятивного среднего чека по группам показал: группа B имеет более высокий средний чек. После определенной точки на графике(2019-08-17) группа B демонстрирует значительное увеличение среднего чека по сравнению с группой A. **Это может указывать на более эффективную стратегию применяемую к группе или наличие более крупных заказов в группе B.**
#
#   При этом острый пик в группе B может быть результатом аномально крупных заказов или выбросов. Такие резкие изменения могут исказить общую картину, и их следует проверить дополнительно.
#
#
# * График относительного изменения кумулятивного среднего чека группы B к группе A показал, что относительные изменения в среднем чеке колеблются в течение всего периода, что указывает на нестабильность и возможное наличие аномальных данных или выбросов, особенно если эти колебания крупные.
#
#   Поскольку график пересекает нулевую отметку несколько раз, это говорит о том, что были моменты, когда средний чек группы В был ниже, чем у группы А. **Однако, более длительный промежуток времени средний чек группы В выше, чем у группы А.**
#
#
# * График кумулятивного среднего количества заказов на посетителя по группам проиллюстрировал, что группа A показывает более низкое среднее количество заказов на посетителя по сравнению с группой B на протяжении большей части теста. **Это может означать, что изменения, протестированные в группе A, были менее эффективны в плане стимулирования большего количества заказов на одного посетителя.**
#
#
# * График относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A показал, что вначале теста группа B сильно проигрывала группе А, однако график показывает положительный относительный прирост у группы В по сравнению с группой A, что может указывать **на более высокую эффективность изменений, внедренных в группе B.**
#
#   В конце представленного периода наблюдается тенденция к увеличению относительного прироста для группы B. Это может свидетельствовать о накопительном эффекте изменений, которые были проведены в группе B.
#
#
# * Сравнение среднего количества заказов на посетителя между группами (без аномалий):
#
#   p-value: 0.01223 – Это значение меньше 0.05, что указывает на наличие статистически значимых различий в среднем количестве заказов на посетителя между группами. **Мы можем отвергнуть нулевую гипотезу и принять альтернативную, которая предполагает, что между группами есть различия в среднем количестве заказов на посетителя .**
#
#   Относительное различие в среднем: 18% – Это довольно значительное относительное различие, которое указывает на то, что одна из групп имеет более высокое среднее количество заказов на посетителя по сравнению с другой группой.
#
#
# * Сравнение среднего чека заказа между группами (без аномалий):
#
#   p-value: 0.85 – Это значение p-value высоко, что означает, что нет статистически значимых различий в среднем чеке между группами. Поскольку значение p-value выше 0.05, **мы не можем отвергнуть нулевую гипотезу о том, что различия в среднем чеке между группами отсутствуют.**
#
#   Относительное различие в среднем: -0.006 – Несмотря на отсутствие статистической значимости, есть небольшое относительное различие в среднем чеке(среднее значение чека группы В на 0.6% меньше, чем у группы А.)
#
# Таким образом, хотя средний чек между группами не отличается статистически значимым образом, количество заказов на посетителя значительно различается. Это может указывать на то, что влияние, оказываемое изменением, тестируемым в А/Б-тесте, сильнее сказывается на количестве заказов, чем на среднем чеке.
# Важно также учитывать контекст теста (например, тип изменений, которые были внесены, характеристики групп и т.д.), чтобы полностью понять, почему может наблюдаться такая разница в поведении между двумя группами.

# %% [markdown]
# ### Примем решение по результатам теста.
#
# Варианты решений:
# - Остановить тест, зафиксировать победу одной из групп.
# - Остановить тест, зафиксировать отсутствие различий между группами.
# - Продолжить тест.

# %% [markdown]
# Исходя из вышеизложенного анализа, следует принять решение остановить тест, зафиксировать победу группы В
#
# Так как наша главная цель - увеличение выручки после внесения изменений, то при той же средней сумме чека, но повышении количества заказов общая сумма выручки возрастет.

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
#
#   <b>Чек-лист доработок</b>
#
#
#   📃 Сформулировать нулевую и альтернативную гипотезы.
#
#   📃 Проверить выводы теста среднего чека по сырым и очищенным данным.
#
#   📃 Пересмотреть результат теста и  откорректировать общий вывод.
#
# Жду твой проект на повторное ревью. Не стесняйся оставлять комментарии и задавать вопросы. Удачи! Все получится.
# </div>
